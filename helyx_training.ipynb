# %% [markdown]
# # Master Thesis - Vignoli Lorenzo
#
# ---
#
# ## 🐙 Helyx training

# %% [markdown]
# ## ⚙️ Import Libraries

# %%
# Libraries
import os
import glob
import random
import warnings
import numpy as np # type: ignore
from sklearn.model_selection import train_test_split # type: ignore

import torch # type: ignore
import torch.nn as nn # type: ignore
import torch.optim as optim # type: ignore
from torch.utils.data import Dataset, DataLoader # type: ignore
import torch.nn.functional as F # type: ignore
import shutil
import plotly.graph_objects as go # type: ignore
from torch.optim.lr_scheduler import LinearLR, ReduceLROnPlateau # type: ignore
import torchvision.transforms as T
import torchvision.transforms.functional as TF

import matplotlib.pyplot as plt # type: ignore
import random
import sys
from torch.amp import GradScaler, autocast # type: ignore

warnings.filterwarnings("ignore")
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.backends.cudnn.deterministic = False
torch.backends.cudnn.benchmark = False

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# ## ⏳ Load and process the Data

# %%
if True:

    for split in ["train", "val", "test"]:
        shutil.rmtree(f"images/{split}", ignore_errors=True)
        shutil.rmtree(f"labels/{split}", ignore_errors=True)
        shutil.rmtree(f"DELTAL/{split}", ignore_errors=True)
        os.makedirs(f"images/{split}", exist_ok=True)
        os.makedirs(f"labels/{split}", exist_ok=True)
        os.makedirs(f"DELTAL/{split}", exist_ok=True)

    dataset_files = sorted(glob.glob("Dataset*.pt"))
    total_originals = sum([len(torch.load(f)["X_images"]) for f in dataset_files])
    all_indices = np.arange(total_originals)

    train_idx, temp_idx = train_test_split(all_indices, test_size=0.15)
    val_idx, test_idx = train_test_split(temp_idx, test_size=1/3)

    split_map = np.full(total_originals, "", dtype=object)
    split_map[train_idx] = "train"
    split_map[val_idx] = "val"
    split_map[test_idx] = "test"

    global_index = {
        "train": 0,
        "val": 0,
        "test": 0
    }

    current_idx = 0

    for file in dataset_files:

        print(f"\n Processing {file}...")
        data = torch.load(file)
        X_images = data["X_images"]
        y = data["y"]
        X_DELTAL = data["X_DELTAL"]

        for i in range(len(X_images)):

            split = split_map[current_idx]
            image_tensor = X_images[i]
            label_tensor = y[i]
            deltal_tensor = X_DELTAL[i]

            idx_str = f"{global_index[split]:06d}"

            torch.save(image_tensor, f"images/{split}/img_{idx_str}.pt")
            torch.save(label_tensor, f"labels/{split}/label_{idx_str}.pt")
            torch.save(deltal_tensor, f"DELTAL/{split}/deltal_{idx_str}.pt")

            global_index[split] = global_index[split] + 1
            current_idx += 1

            percent = (current_idx / total_originals) * 100
            sys.stdout.write(f"\rProgress: {percent:.2f}%")
            sys.stdout.flush()

        del X_images
        del y
        del X_DELTAL

    print("\n Finished dataset generation.")
# Out:
#  Processing Dataset1.pt...
# Progress: 3.23%
#  Processing Dataset10.pt...
# Progress: 6.45%
#  Processing Dataset11.pt...
# Progress: 9.68%
#  Processing Dataset12.pt...
# Progress: 12.90%
#  Processing Dataset13.pt...
# Progress: 16.13%
#  Processing Dataset14.pt...
# Progress: 19.35%
#  Processing Dataset15.pt...
# Progress: 22.58%
#  Processing Dataset16.pt...
# Progress: 25.81%
#  Processing Dataset17.pt...
# Progress: 29.03%
#  Processing Dataset18.pt...
# Progress: 32.26%
#  Processing Dataset19.pt...
# Progress: 35.48%
#  Processing Dataset2.pt...
# Progress: 38.71%
#  Processing Dataset20.pt...
# Progress: 41.94%
#  Processing Dataset21.pt...
# Progress: 45.16%
#  Processing Dataset22.pt...
# Progress: 48.39%
#  Processing Dataset23.pt...
# Progress: 51.61%
#  Processing Dataset24.pt...
# Progress: 54.84%
#  Processing Dataset25.pt...
# Progress: 58.06%
#  Processing Dataset26.pt...
# Progress: 61.29%
#  Processing Dataset27.pt...
# Progress: 64.52%
#  Processing Dataset28.pt...
# Progress: 67.74%
#  Processing Dataset29.pt...
# Progress: 70.97%
#  Processing Dataset3.pt...
# Progress: 74.19%
#  Processing Dataset30.pt...
# Progress: 77.42%
#  Processing Dataset31.pt...
# Progress: 80.65%
#  Processing Dataset4.pt...
# Progress: 83.87%
#  Processing Dataset5.pt...
# Progress: 87.10%
#  Processing Dataset6.pt...
# Progress: 90.32%
#  Processing Dataset7.pt...
# Progress: 93.55%
#  Processing Dataset8.pt...
# Progress: 96.77%
#  Processing Dataset9.pt...
# Progress: 100.00%
#  Finished dataset generation.

# %%
if True:
    label_paths = sorted(glob.glob("labels/train/*.pt"))
    all_labels = torch.stack([torch.load(p).float() for p in label_paths])
    mean = all_labels.mean(dim=0)
    std = all_labels.std(dim=0)
    torch.save({'mean': mean, 'std': std}, 'label_stats.pt')

    del mean, std

# %%
class ImageRegressionDataset(Dataset):
    def __init__(self, image_paths, label_paths, split="train"):
        self.image_paths = image_paths
        self.label_paths = label_paths
        self.augment = split == "train"

    def __len__(self):
        return len(self.image_paths)

    def apply_blur(self, image, kernel_size=5, sigma_max=6.0):
        sigma = random.uniform(0.0, sigma_max)
        image = image.float().unsqueeze(0) / 255.0
        image = TF.gaussian_blur(image, kernel_size=kernel_size, sigma=sigma)
        return (image.squeeze(0) * 255.0).clamp(0, 255).to(torch.uint8)

    def add_gaussian_noise(self, image, std_max=30.0):
        std = random.uniform(0.0, std_max)
        noise = torch.randn_like(image.float()) * std
        image = image.float() + noise
        return image.clamp(0, 255).to(torch.uint8)

    def apply_color_jitter(self, image, brightness=0.25, contrast=0.3):
        image = image.float().unsqueeze(0) / 255.0
        b = 1.0 + random.uniform(-brightness, brightness)
        c = 1.0 + random.uniform(-contrast, contrast)
        image = TF.adjust_brightness(image, b)
        image = TF.adjust_contrast(image, c)
        return (image.squeeze(0) * 255.0).clamp(0, 255).to(torch.uint8)

    def apply_brightness_shift(self, image, offset_max=0.2):
        offset = random.choice([-offset_max, offset_max])
        image = (image.float() / 255.0 + offset).clamp(0.0, 1.0)
        return (image * 255.0).to(torch.uint8)

    def apply_vignette(self, image, strength_max=0.6):
        strength = strength_max
        H, W = image.shape[1:]
        Y, X = torch.meshgrid(torch.linspace(-1, 1, H), torch.linspace(-1, 1, W), indexing='ij')
        radius = torch.sqrt(X**2 + Y**2)
        mask = 1.0 - strength * radius**2
        mask = mask.clamp(0.75, 1.0).unsqueeze(0)
        image = (image.float() / 255.0 * mask).clamp(0.0, 1.0)
        return (image * 255.0).to(torch.uint8)

    def __getitem__(self, idx):
        image = torch.load(self.image_paths[idx]).to(torch.uint8)
        label = torch.load(self.label_paths[idx]).float()

        if self.augment:
            image = self.apply_blur(image)
            image = self.add_gaussian_noise(image)
            image = self.apply_color_jitter(image)
            image = self.apply_brightness_shift(image)
            image = self.apply_vignette(image)

        return image, label

# %%
# Load sorted image and label paths
def get_paths(split):
    image_dir = os.path.join("images", split)
    label_dir = os.path.join("labels", split)
    image_paths = sorted([os.path.join(image_dir, f) for f in os.listdir(image_dir) if f.endswith(".pt")])
    label_paths = sorted([os.path.join(label_dir, f) for f in os.listdir(label_dir) if f.endswith(".pt")])
    assert len(image_paths) == len(label_paths)
    return image_paths, label_paths

# Get paths for each split
train_img, train_lbl = get_paths("train")
val_img, val_lbl = get_paths("val")
test_img, test_lbl = get_paths("test")

# Dataset dimensions
print(f"Processed: \n {len(train_img)} training images \n {len(val_img)} validation images \n {len(test_img)} test images")

# Create datasets
train_dataset = ImageRegressionDataset(train_img, train_lbl)
val_dataset = ImageRegressionDataset(val_img, val_lbl)
test_dataset = ImageRegressionDataset(test_img, test_lbl)

# Create dataloaders (ottimizzati)
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True,
                          num_workers=12, pin_memory=True, persistent_workers=True)

val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False,
                        num_workers=12, pin_memory=True, persistent_workers=True)

test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False,
                         num_workers=12, pin_memory=True, persistent_workers=True)
# Out:
# Processed:
#  26350 training images
#  3100 validation images
#  1550 test images

# %% [markdown]
# ## ⚓ Network definition

# %%
class Markers(nn.Module):
    def __init__(self, alpha=0.18):
        super().__init__()
        self.alpha = alpha

    def rgb_to_hsv(self, x):
        r, g, b = x[:, 0], x[:, 1], x[:, 2]
        maxc, _ = x.max(dim=1)
        minc, _ = x.min(dim=1)
        v = maxc
        eps = 1e-8

        deltac = maxc - minc
        s = deltac / (maxc + eps)
        s[maxc == 0] = 0

        rc = (maxc - r) / (deltac + eps)
        gc = (maxc - g) / (deltac + eps)
        bc = (maxc - b) / (deltac + eps)

        h = torch.zeros_like(maxc)
        h[maxc == r] = (bc - gc)[maxc == r]
        h[maxc == g] = 2.0 + (rc - bc)[maxc == g]
        h[maxc == b] = 4.0 + (gc - rc)[maxc == b]
        h = (h / 6.0) % 1.0
        h[deltac == 0] = 0.0

        return torch.stack([h, s, v], dim=1)

    def forward(self, x):
        hsv = self.rgb_to_hsv(x)
        h, s, v = hsv[:, 0], hsv[:, 1], hsv[:, 2]

        green = ((h > 0.25) & (h < 0.45) & (s > 0.3) & (v > 0.2))
        black = (v < 0.3)
        mask = (green | black).unsqueeze(1)  # [B, 1, H, W]

        x_out = x * self.alpha
        x_out[mask.expand_as(x_out)] = 1.0

        return x_out

# %%
# Load one random image
paths = sorted(glob.glob("images/train/*.pt"))
path = random.choice(paths)
image = torch.load(path).float() / 255.0  # [3, H, W]

# Augmentation
def apply_all_augmentations_random(image):
    sigma = random.uniform(0.0, 6.0)
    image = TF.gaussian_blur(image.unsqueeze(0), kernel_size=5, sigma=sigma).squeeze(0)

    noise_std = random.uniform(0.0, 30.0) / 255.0
    noise = torch.randn_like(image) * noise_std
    image = (image + noise).clamp(0.0, 1.0)

    brightness = 1.0 + random.uniform(-0.25, 0.25)
    contrast = 1.0 + random.uniform(-0.3, 0.3)
    image = TF.adjust_brightness(image.unsqueeze(0), brightness).squeeze(0)
    image = TF.adjust_contrast(image.unsqueeze(0), contrast).squeeze(0)

    offset = random.choice([-0.2, 0.2])
    image = (image + offset).clamp(0.0, 1.0)

    H, W = image.shape[1:]
    Y, X = torch.meshgrid(torch.linspace(-1, 1, H), torch.linspace(-1, 1, W), indexing='ij')
    radius = torch.sqrt(X**2 + Y**2)
    strength = random.uniform(0.0, 0.6)
    mask = 1.0 - strength * radius**2
    mask = mask.clamp(0.75, 1.0).unsqueeze(0)
    image = (image * mask).clamp(0.0, 1.0)

    return image

# Apply
augmented = apply_all_augmentations_random(image)
markers = Markers()
processed = markers(augmented.unsqueeze(0))[0]

# Visualize
plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.imshow(image.permute(1, 2, 0).cpu())
plt.title("Original RGB")
plt.axis("off")

plt.subplot(1, 3, 2)
plt.imshow(augmented.permute(1, 2, 0).cpu())
plt.title("Augmented (random, extreme)")
plt.axis("off")

plt.subplot(1, 3, 3)
plt.imshow(processed.permute(1, 2, 0).cpu())
plt.title("With Markers (α = 0.18)")
plt.axis("off")

plt.tight_layout()
plt.show()

# %%
from torchvision.models import mobilenet_v2

class NetCamera(nn.Module):
    def __init__(self):
        super().__init__()
        self.markers = Markers()
        base = mobilenet_v2(pretrained=True)
        self.encoder = base.features  # [B, 1280, H, W]
        self.pool = nn.AdaptiveAvgPool2d(1)

        self.head = nn.Sequential(
            nn.Flatten(),
            nn.Linear(1280, 6)
        )

    def forward(self, x):
        x = x / 255.0
        x = self.markers(x)
        x = self.encoder(x)
        x = self.pool(x)
        x = self.head(x)
        return x

# %% [markdown]
# ## 😓 Training

# %%
model = NetCamera().to(device)

# Check the number of parameters
total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"Total trainable parameters: {total_params:,}")

criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=5e-4, weight_decay=1e-4)

# Learning rate management
scheduler = LinearLR(optimizer, start_factor = 1e-3, end_factor = 1.0, total_iters = 10)
plateau_scheduler = ReduceLROnPlateau(optimizer, mode = 'min', factor = 0.9, patience=20, verbose=True)
# Out:
# Total trainable parameters: 2,231,558

# %%
best_val_loss = float('inf')
patience = 30
counter = 0

# Normalization parameters
stats = torch.load("label_stats.pt")
mean = stats['mean'].to(device)
std = stats['std'].to(device)

# %%
history_train = []
history_val = []

scaler = GradScaler(device='cuda')

accumulation_steps = max(1, len(train_loader) // 5)
optimizer.zero_grad()
epochs = 300

for epoch in range(epochs):
    model.train()
    train_losses = []
    total_batches = len(train_loader)

    for i, (images, labels) in enumerate(train_loader):
        images = images.to(device)
        labels = labels.to(device)

        with autocast(device_type='cuda'):
            labels_norm = (labels - mean) / std
            preds = model(images)
            loss = criterion(preds, labels_norm)

        loss = loss / accumulation_steps
        scaler.scale(loss).backward()

        train_losses.append(loss.item() * accumulation_steps)

        progress = (i + 1) / total_batches * 100
        sys.stdout.write(f"\rEpoch {epoch + 1}: {progress:.1f}%")
        sys.stdout.flush()

        # Perform gradient update at the end of the accumulation steps
        if (i + 1) % accumulation_steps == 0 or (i + 1) == total_batches:
            scaler.step(optimizer)
            scaler.update()
            optimizer.zero_grad()

    model.eval()
    val_losses = []

    with torch.no_grad():
        for images, labels in val_loader:
            images = images.to(device)
            labels = labels.to(device)

            with autocast(device_type='cuda'):
                labels_norm = (labels - mean) / std
                preds = model(images)
                loss = criterion(preds, labels_norm)

            val_losses.append(loss.item())

    avg_train_loss = np.mean(train_losses)
    avg_val_loss = np.mean(val_losses)
    scheduler.step()

    plateau_scheduler.step(avg_val_loss)
    history_train.append(avg_train_loss)
    history_val.append(avg_val_loss)

    sys.stdout.write("\r")
    current_lr = optimizer.param_groups[0]['lr']
    print(f"Epoch {epoch + 1} | Train Loss: {avg_train_loss:.4f} | Val Loss: {avg_val_loss:.4f} | LR: {current_lr:.6f}")

    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        torch.save(model, "helyx_model_normalized.pt")
        counter = 0
    else:
        counter += 1
        if counter >= patience:
            print("Early stopping triggered.")
            break

del model
del stats
del mean
del std
del optimizer
del scheduler
del plateau_scheduler
del scaler
# Out:
# Epoch 1 | Train Loss: 1.1986 | Val Loss: 1.1864 | LR: 0.000050
# Epoch 2 | Train Loss: 1.1028 | Val Loss: 0.9511 | LR: 0.000100
# Epoch 3 | Train Loss: 0.8440 | Val Loss: 0.6255 | LR: 0.000150
# Epoch 4 | Train Loss: 0.5444 | Val Loss: 0.3303 | LR: 0.000200
# Epoch 5 | Train Loss: 0.3323 | Val Loss: 0.2122 | LR: 0.000250
# Epoch 6 | Train Loss: 0.2144 | Val Loss: 0.1312 | LR: 0.000300
# Epoch 7 | Train Loss: 0.1574 | Val Loss: 0.0926 | LR: 0.000350
# Epoch 8 | Train Loss: 0.1257 | Val Loss: 0.0658 | LR: 0.000400
# Epoch 9 | Train Loss: 0.1125 | Val Loss: 0.0485 | LR: 0.000450
# Epoch 10 | Train Loss: 0.0980 | Val Loss: 0.0601 | LR: 0.000500
# Epoch 11 | Train Loss: 0.0914 | Val Loss: 0.0339 | LR: 0.000500
# Epoch 12 | Train Loss: 0.0811 | Val Loss: 0.0300 | LR: 0.000500
# Epoch 13 | Train Loss: 0.0746 | Val Loss: 0.0301 | LR: 0.000500
# Epoch 14 | Train Loss: 0.0690 | Val Loss: 0.0322 | LR: 0.000500
# Epoch 15 | Train Loss: 0.0642 | Val Loss: 0.0268 | LR: 0.000500
# Epoch 16 | Train Loss: 0.0583 | Val Loss: 0.0265 | LR: 0.000500
# Epoch 17 | Train Loss: 0.0527 | Val Loss: 0.0268 | LR: 0.000500
# Epoch 18 | Train Loss: 0.0496 | Val Loss: 0.0315 | LR: 0.000500
# Epoch 19 | Train Loss: 0.0470 | Val Loss: 0.0376 | LR: 0.000500
# Epoch 20 | Train Loss: 0.0463 | Val Loss: 0.0296 | LR: 0.000500
# Epoch 21 | Train Loss: 0.0444 | Val Loss: 0.0332 | LR: 0.000500
# Epoch 22 | Train Loss: 0.0519 | Val Loss: 0.0284 | LR: 0.000500
# Epoch 23 | Train Loss: 0.0449 | Val Loss: 0.0265 | LR: 0.000500
# Epoch 24 | Train Loss: 0.0500 | Val Loss: 0.0259 | LR: 0.000500
# Epoch 25 | Train Loss: 0.0423 | Val Loss: 0.0285 | LR: 0.000500
# Epoch 26 | Train Loss: 0.0392 | Val Loss: 0.0306 | LR: 0.000500
# Epoch 27 | Train Loss: 0.0350 | Val Loss: 0.0284 | LR: 0.000500
# Epoch 28 | Train Loss: 0.0328 | Val Loss: 0.0325 | LR: 0.000500
# Epoch 29 | Train Loss: 0.0304 | Val Loss: 0.0219 | LR: 0.000500
# Epoch 30 | Train Loss: 0.0286 | Val Loss: 0.0164 | LR: 0.000500
# Epoch 31 | Train Loss: 0.0342 | Val Loss: 0.0324 | LR: 0.000500
# Epoch 32 | Train Loss: 0.0380 | Val Loss: 0.0392 | LR: 0.000500
# Epoch 33 | Train Loss: 0.0400 | Val Loss: 0.0299 | LR: 0.000500
# Epoch 34 | Train Loss: 0.0385 | Val Loss: 0.0189 | LR: 0.000500
# Epoch 35 | Train Loss: 0.0296 | Val Loss: 0.0190 | LR: 0.000500
# Epoch 36 | Train Loss: 0.0276 | Val Loss: 0.0162 | LR: 0.000500
# Epoch 37 | Train Loss: 0.0235 | Val Loss: 0.0209 | LR: 0.000500
# Epoch 38 | Train Loss: 0.0239 | Val Loss: 0.0200 | LR: 0.000500
# Epoch 39 | Train Loss: 0.0270 | Val Loss: 0.0222 | LR: 0.000500
# Epoch 40 | Train Loss: 0.0277 | Val Loss: 0.0263 | LR: 0.000500
# Epoch 41 | Train Loss: 0.0270 | Val Loss: 0.0233 | LR: 0.000500
# Epoch 42 | Train Loss: 0.0243 | Val Loss: 0.0216 | LR: 0.000500
# Epoch 43 | Train Loss: 0.0237 | Val Loss: 0.0271 | LR: 0.000500
# Epoch 44 | Train Loss: 0.0241 | Val Loss: 0.0208 | LR: 0.000500
# Epoch 45 | Train Loss: 0.0282 | Val Loss: 0.0268 | LR: 0.000500
# Epoch 46 | Train Loss: 0.0305 | Val Loss: 0.0193 | LR: 0.000500
# Epoch 47 | Train Loss: 0.0267 | Val Loss: 0.0167 | LR: 0.000500
# Epoch 48 | Train Loss: 0.0230 | Val Loss: 0.0169 | LR: 0.000500
# Epoch 49 | Train Loss: 0.0208 | Val Loss: 0.0135 | LR: 0.000500
# Epoch 50 | Train Loss: 0.0184 | Val Loss: 0.0145 | LR: 0.000500
# Epoch 51 | Train Loss: 0.0186 | Val Loss: 0.0149 | LR: 0.000500
# Epoch 52 | Train Loss: 0.0219 | Val Loss: 0.0155 | LR: 0.000500
# Epoch 53 | Train Loss: 0.0190 | Val Loss: 0.0156 | LR: 0.000500
# Epoch 54 | Train Loss: 0.0195 | Val Loss: 0.0158 | LR: 0.000500
# Epoch 55 | Train Loss: 0.0200 | Val Loss: 0.0142 | LR: 0.000500
# Epoch 56 | Train Loss: 0.0187 | Val Loss: 0.0170 | LR: 0.000500
# Epoch 57 | Train Loss: 0.0204 | Val Loss: 0.0208 | LR: 0.000500
# Epoch 58 | Train Loss: 0.0251 | Val Loss: 0.0251 | LR: 0.000500
# Epoch 59 | Train Loss: 0.0312 | Val Loss: 0.0174 | LR: 0.000500
# Epoch 60 | Train Loss: 0.0220 | Val Loss: 0.0185 | LR: 0.000500
# Epoch 61 | Train Loss: 0.0203 | Val Loss: 0.0172 | LR: 0.000500
# Epoch 62 | Train Loss: 0.0190 | Val Loss: 0.0163 | LR: 0.000500
# Epoch 63 | Train Loss: 0.0176 | Val Loss: 0.0152 | LR: 0.000500
# Epoch 64 | Train Loss: 0.0172 | Val Loss: 0.0180 | LR: 0.000500
# Epoch 65 | Train Loss: 0.0184 | Val Loss: 0.0198 | LR: 0.000500
# Epoch 66 | Train Loss: 0.0200 | Val Loss: 0.0160 | LR: 0.000500
# Epoch 67 | Train Loss: 0.0185 | Val Loss: 0.0123 | LR: 0.000500
# Epoch 68 | Train Loss: 0.0157 | Val Loss: 0.0137 | LR: 0.000500
# Epoch 69 | Train Loss: 0.0173 | Val Loss: 0.0166 | LR: 0.000500
# Epoch 70 | Train Loss: 0.0183 | Val Loss: 0.0137 | LR: 0.000500
# Epoch 71 | Train Loss: 0.0182 | Val Loss: 0.0155 | LR: 0.000500
# Epoch 72 | Train Loss: 0.0179 | Val Loss: 0.0158 | LR: 0.000500
# Epoch 73 | Train Loss: 0.0185 | Val Loss: 0.0132 | LR: 0.000500
# Epoch 74 | Train Loss: 0.0191 | Val Loss: 0.0123 | LR: 0.000500
# Epoch 75 | Train Loss: 0.0167 | Val Loss: 0.0139 | LR: 0.000500
# Epoch 76 | Train Loss: 0.0143 | Val Loss: 0.0119 | LR: 0.000500
# Epoch 77 | Train Loss: 0.0136 | Val Loss: 0.0114 | LR: 0.000500
# Epoch 78 | Train Loss: 0.0131 | Val Loss: 0.0119 | LR: 0.000500
# Epoch 79 | Train Loss: 0.0135 | Val Loss: 0.0137 | LR: 0.000500
# Epoch 80 | Train Loss: 0.0155 | Val Loss: 0.0158 | LR: 0.000500
# Epoch 81 | Train Loss: 0.0184 | Val Loss: 0.0148 | LR: 0.000500
# Epoch 82 | Train Loss: 0.0185 | Val Loss: 0.0254 | LR: 0.000500
# Epoch 83 | Train Loss: 0.0222 | Val Loss: 0.0152 | LR: 0.000500
# Epoch 84 | Train Loss: 0.0166 | Val Loss: 0.0137 | LR: 0.000500
# Epoch 85 | Train Loss: 0.0154 | Val Loss: 0.0147 | LR: 0.000500
# Epoch 86 | Train Loss: 0.0167 | Val Loss: 0.0202 | LR: 0.000500
# Epoch 87 | Train Loss: 0.0203 | Val Loss: 0.0120 | LR: 0.000500
# Epoch 88 | Train Loss: 0.0177 | Val Loss: 0.0148 | LR: 0.000500
# Epoch 89 | Train Loss: 0.0169 | Val Loss: 0.0132 | LR: 0.000500
# Epoch 90 | Train Loss: 0.0165 | Val Loss: 0.0118 | LR: 0.000500
# Epoch 91 | Train Loss: 0.0143 | Val Loss: 0.0126 | LR: 0.000500
# Epoch 92 | Train Loss: 0.0144 | Val Loss: 0.0125 | LR: 0.000500
# Epoch 93 | Train Loss: 0.0144 | Val Loss: 0.0144 | LR: 0.000500
# Epoch 94 | Train Loss: 0.0145 | Val Loss: 0.0130 | LR: 0.000500
# Epoch 95 | Train Loss: 0.0153 | Val Loss: 0.0153 | LR: 0.000500
# Epoch 96 | Train Loss: 0.0154 | Val Loss: 0.0144 | LR: 0.000500
# Epoch 97 | Train Loss: 0.0160 | Val Loss: 0.0117 | LR: 0.000500
# Epoch 98 | Train Loss: 0.0137 | Val Loss: 0.0120 | LR: 0.000450
# Epoch 99 | Train Loss: 0.0130 | Val Loss: 0.0114 | LR: 0.000450
# Epoch 100 | Train Loss: 0.0126 | Val Loss: 0.0110 | LR: 0.000450
# Epoch 101 | Train Loss: 0.0122 | Val Loss: 0.0125 | LR: 0.000450
# Epoch 102 | Train Loss: 0.0119 | Val Loss: 0.0129 | LR: 0.000450
# Epoch 103 | Train Loss: 0.0126 | Val Loss: 0.0136 | LR: 0.000450
# Epoch 104 | Train Loss: 0.0134 | Val Loss: 0.0159 | LR: 0.000450
# Epoch 105 | Train Loss: 0.0141 | Val Loss: 0.0135 | LR: 0.000450
# Epoch 106 | Train Loss: 0.0153 | Val Loss: 0.0154 | LR: 0.000450
# Epoch 107 | Train Loss: 0.0160 | Val Loss: 0.0133 | LR: 0.000450
# Epoch 108 | Train Loss: 0.0147 | Val Loss: 0.0125 | LR: 0.000450
# Epoch 109 | Train Loss: 0.0152 | Val Loss: 0.0131 | LR: 0.000450
# Epoch 110 | Train Loss: 0.0148 | Val Loss: 0.0132 | LR: 0.000450
# Epoch 111 | Train Loss: 0.0151 | Val Loss: 0.0128 | LR: 0.000450
# Epoch 112 | Train Loss: 0.0130 | Val Loss: 0.0109 | LR: 0.000450
# Epoch 113 | Train Loss: 0.0115 | Val Loss: 0.0116 | LR: 0.000450
# Epoch 114 | Train Loss: 0.0117 | Val Loss: 0.0118 | LR: 0.000450
# Epoch 115 | Train Loss: 0.0138 | Val Loss: 0.0138 | LR: 0.000450
# Epoch 116 | Train Loss: 0.0183 | Val Loss: 0.0123 | LR: 0.000450
# Epoch 117 | Train Loss: 0.0138 | Val Loss: 0.0117 | LR: 0.000450
# Epoch 118 | Train Loss: 0.0133 | Val Loss: 0.0115 | LR: 0.000450
# Epoch 119 | Train Loss: 0.0132 | Val Loss: 0.0125 | LR: 0.000450
# Epoch 120 | Train Loss: 0.0127 | Val Loss: 0.0149 | LR: 0.000450
# Epoch 121 | Train Loss: 0.0134 | Val Loss: 0.0143 | LR: 0.000450
# Epoch 122 | Train Loss: 0.0137 | Val Loss: 0.0130 | LR: 0.000450
# Epoch 123 | Train Loss: 0.0150 | Val Loss: 0.0171 | LR: 0.000450
# Epoch 124 | Train Loss: 0.0163 | Val Loss: 0.0184 | LR: 0.000450
# Epoch 125 | Train Loss: 0.0151 | Val Loss: 0.0121 | LR: 0.000450
# Epoch 126 | Train Loss: 0.0155 | Val Loss: 0.0124 | LR: 0.000450
# Epoch 127 | Train Loss: 0.0143 | Val Loss: 0.0145 | LR: 0.000450
# Epoch 128 | Train Loss: 0.0143 | Val Loss: 0.0135 | LR: 0.000450
# Epoch 129 | Train Loss: 0.0142 | Val Loss: 0.0116 | LR: 0.000450
# Epoch 130 | Train Loss: 0.0126 | Val Loss: 0.0107 | LR: 0.000450
# Epoch 131 | Train Loss: 0.0115 | Val Loss: 0.0113 | LR: 0.000450
# Epoch 132 | Train Loss: 0.0107 | Val Loss: 0.0098 | LR: 0.000450
# Epoch 133 | Train Loss: 0.0109 | Val Loss: 0.0129 | LR: 0.000450
# Epoch 134 | Train Loss: 0.0126 | Val Loss: 0.0129 | LR: 0.000450
# Epoch 135 | Train Loss: 0.0153 | Val Loss: 0.0120 | LR: 0.000450
# Epoch 136 | Train Loss: 0.0114 | Val Loss: 0.0140 | LR: 0.000450
# Epoch 137 | Train Loss: 0.0121 | Val Loss: 0.0150 | LR: 0.000450
# Epoch 138 | Train Loss: 0.0129 | Val Loss: 0.0206 | LR: 0.000450
# Epoch 139 | Train Loss: 0.0141 | Val Loss: 0.0125 | LR: 0.000450
# Epoch 140 | Train Loss: 0.0169 | Val Loss: 0.0159 | LR: 0.000450
# Epoch 141 | Train Loss: 0.0125 | Val Loss: 0.0166 | LR: 0.000450
# Epoch 142 | Train Loss: 0.0136 | Val Loss: 0.0158 | LR: 0.000450
# Epoch 143 | Train Loss: 0.0146 | Val Loss: 0.0128 | LR: 0.000450
# Epoch 144 | Train Loss: 0.0141 | Val Loss: 0.0130 | LR: 0.000450
# Epoch 145 | Train Loss: 0.0128 | Val Loss: 0.0142 | LR: 0.000450
# Epoch 146 | Train Loss: 0.0133 | Val Loss: 0.0126 | LR: 0.000450
# Epoch 147 | Train Loss: 0.0141 | Val Loss: 0.0143 | LR: 0.000450
# Epoch 148 | Train Loss: 0.0139 | Val Loss: 0.0123 | LR: 0.000450
# Epoch 149 | Train Loss: 0.0128 | Val Loss: 0.0127 | LR: 0.000450
# Epoch 150 | Train Loss: 0.0130 | Val Loss: 0.0162 | LR: 0.000450
# Epoch 151 | Train Loss: 0.0155 | Val Loss: 0.0153 | LR: 0.000450
# Epoch 152 | Train Loss: 0.0160 | Val Loss: 0.0126 | LR: 0.000450
# Epoch 153 | Train Loss: 0.0125 | Val Loss: 0.0125 | LR: 0.000405
# Epoch 154 | Train Loss: 0.0119 | Val Loss: 0.0108 | LR: 0.000405
# Epoch 155 | Train Loss: 0.0110 | Val Loss: 0.0102 | LR: 0.000405
# Epoch 156 | Train Loss: 0.0108 | Val Loss: 0.0114 | LR: 0.000405
# Epoch 157 | Train Loss: 0.0103 | Val Loss: 0.0097 | LR: 0.000405
# Epoch 158 | Train Loss: 0.0105 | Val Loss: 0.0107 | LR: 0.000405
# Epoch 159 | Train Loss: 0.0107 | Val Loss: 0.0093 | LR: 0.000405
# Epoch 160 | Train Loss: 0.0106 | Val Loss: 0.0088 | LR: 0.000405
# Epoch 161 | Train Loss: 0.0095 | Val Loss: 0.0102 | LR: 0.000405
# Epoch 162 | Train Loss: 0.0097 | Val Loss: 0.0091 | LR: 0.000405
# Epoch 163 | Train Loss: 0.0106 | Val Loss: 0.0112 | LR: 0.000405
# Epoch 164 | Train Loss: 0.0125 | Val Loss: 0.0116 | LR: 0.000405
# Epoch 165 | Train Loss: 0.0114 | Val Loss: 0.0127 | LR: 0.000405
# Epoch 166 | Train Loss: 0.0120 | Val Loss: 0.0116 | LR: 0.000405
# Epoch 167 | Train Loss: 0.0116 | Val Loss: 0.0132 | LR: 0.000405
# Epoch 168 | Train Loss: 0.0129 | Val Loss: 0.0126 | LR: 0.000405
# Epoch 169 | Train Loss: 0.0131 | Val Loss: 0.0123 | LR: 0.000405
# Epoch 170 | Train Loss: 0.0125 | Val Loss: 0.0127 | LR: 0.000405
# Epoch 171 | Train Loss: 0.0116 | Val Loss: 0.0122 | LR: 0.000405
# Epoch 172 | Train Loss: 0.0109 | Val Loss: 0.0125 | LR: 0.000405
# Epoch 173 | Train Loss: 0.0111 | Val Loss: 0.0133 | LR: 0.000405
# Epoch 174 | Train Loss: 0.0117 | Val Loss: 0.0156 | LR: 0.000405
# Epoch 175 | Train Loss: 0.0118 | Val Loss: 0.0148 | LR: 0.000405
# Epoch 176 | Train Loss: 0.0123 | Val Loss: 0.0158 | LR: 0.000405
# Epoch 177 | Train Loss: 0.0131 | Val Loss: 0.0115 | LR: 0.000405
# Epoch 178 | Train Loss: 0.0135 | Val Loss: 0.0124 | LR: 0.000405
# Epoch 179 | Train Loss: 0.0130 | Val Loss: 0.0115 | LR: 0.000405
# Epoch 180 | Train Loss: 0.0116 | Val Loss: 0.0113 | LR: 0.000405
# Epoch 181 | Train Loss: 0.0104 | Val Loss: 0.0140 | LR: 0.000365
# Epoch 182 | Train Loss: 0.0103 | Val Loss: 0.0122 | LR: 0.000365
# Epoch 183 | Train Loss: 0.0097 | Val Loss: 0.0105 | LR: 0.000365
# Epoch 184 | Train Loss: 0.0092 | Val Loss: 0.0102 | LR: 0.000365
# Epoch 185 | Train Loss: 0.0091 | Val Loss: 0.0095 | LR: 0.000365
# Epoch 186 | Train Loss: 0.0092 | Val Loss: 0.0098 | LR: 0.000365
# Epoch 187 | Train Loss: 0.0096 | Val Loss: 0.0095 | LR: 0.000365
# Epoch 188 | Train Loss: 0.0099 | Val Loss: 0.0121 | LR: 0.000365
# Epoch 189 | Train Loss: 0.0108 | Val Loss: 0.0103 | LR: 0.000365
# Epoch 190 | Train Loss: 0.0113 | Val Loss: 0.0125 | LR: 0.000365
# Early stopping triggered.

# %%
plt.figure(figsize=(10, 5))
plt.plot(history_train, label='Train MSE')
plt.plot(history_val, label='Val MSE')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
class DenormalizedModel(nn.Module):
    def __init__(self, base_model, mean, std):
        super().__init__()
        self.base_model = base_model
        self.register_buffer("mean", mean)
        self.register_buffer("std", std)

    def forward(self, x):
        out = self.base_model(x)
        return out * self.std + self.mean

# %%
model = torch.load("helyx_model_normalized.pt")
stats = torch.load("label_stats.pt")

# Model and parameters
model = model.to(device)
mean = stats['mean'].to(device)
std = stats['std'].to(device)

# Save final model
final_model = DenormalizedModel(model, mean, std)
torch.save(final_model, "helyx_model.pt")

del final_model
del stats

# %% [markdown]
# ## ⏰ Testing

# %%
# Load full model
model = torch.load("helyx_model.pt")
model_normalized = torch.load("helyx_model_normalized.pt")
stats = torch.load("label_stats.pt")
mean = stats['mean'].to(device)
std = stats['std'].to(device)
model = model.to(device)
model_normalized = model_normalized.to(device)
model.eval()
model_normalized.eval()

all_preds = []
all_preds_normalized = []
all_labels = []
all_labels_normalized = []

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)
        labels_normalized = (labels - mean) / std

        preds = model(images)
        preds_normalized = model_normalized(images)
        all_preds.append(preds.cpu().numpy())
        all_labels.append(labels.cpu().numpy())
        all_preds_normalized.append(preds_normalized.cpu().numpy())
        all_labels_normalized.append(labels_normalized.cpu().numpy())
        del images, labels, preds, preds_normalized

print("\n")

all_preds = np.concatenate(all_preds, axis=0)
all_labels = np.concatenate(all_labels, axis=0)
all_preds_normalized = np.concatenate(all_preds_normalized, axis=0)
all_labels_normalized = np.concatenate(all_labels_normalized, axis=0)

mae_normalized = np.mean(np.abs(all_preds_normalized - all_labels_normalized))
mse_normalized = np.mean((all_preds_normalized - all_labels_normalized) ** 2)
print(f"Test MSE - normalized: {mse_normalized:.4f}")
print(f"Test MAE - normalized: {mae_normalized:.4f}")

all_preds[:, 3:] = np.rad2deg(all_preds[:, 3:])
all_labels[:, 3:] = np.rad2deg(all_labels[:, 3:])

param_names = ['X [mm]', 'Y [mm]', 'Z [mm]', 'Yaw [°]', 'Pitch [°]', 'Roll [°]']
fig, axes = plt.subplots(2, 3, figsize=(15, 8))

for i, ax in enumerate(axes.flatten()):
    mae = np.mean(np.abs(all_preds[:, i] - all_labels[:, i]))  # Calculate MAE
    max_mae = np.max(np.abs(all_preds[:, i] - all_labels[:, i]))
    min_mae = np.min(np.abs(all_preds[:, i] - all_labels[:, i]))
    ax.plot(all_labels[:, i], label='True', alpha=0.7)
    ax.plot(all_preds[:, i], label='Pred', alpha=0.7)
    ax.set_title(f"{param_names[i]} - mean MAE: {mae:.2f}")
    ax.grid(True)

axes[0, 0].legend()
plt.tight_layout()
plt.show()
# Out:
# Test MSE - normalized: 0.0091
# Test MAE - normalized: 0.0642
